# %% [markdown]
# # House Price Prediction using Machine Learning
#
# ## Objective
#
# The objective of this project is to build a machine learning model that predicts the selling price of houses based on various features such as lot size, neighborhood, number of rooms, year built, garage capacity, and other property characteristics.
#
# This project uses the **House Prices Advanced Regression Techniques** dataset from Kaggle

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## loading Dataset

# %%
df=pd.read_csv("data/train.csv")

# %% [markdown]
# # Phase-1 Data Inspection

# %% [markdown]
# ## Preview Dataset

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## Cheking Dimensions

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# ## Columns Names

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# ## Dataset Information

# %%
df.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ## Statistical Summary

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ## Cheking Missing Values

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# # Phase-2 DATA CLEANING

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# ## Columns with missing values

# %%
missing_values[missing_values > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# ## Fill Missing Values

# %%
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].median())
df["MasVnrArea"] = df["MasVnrArea"].fillna(df["MasVnrArea"].median())

df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])
df["MasVnrType"] = df["MasVnrType"].fillna("None")
df["MasVnrArea"] = df["MasVnrArea"].fillna(0)

# %%
df['BsmtQual'] = df['BsmtQual'].fillna('no basement')
df['BsmtCond'] = df['BsmtCond'].fillna('no basement')
df['BsmtFinType1'] = df['BsmtFinType1'].fillna('no basement')
df['BsmtFinType2'] = df['BsmtFinType2'].fillna('no basement')
df['BsmtExposure'] = df['BsmtExposure'].fillna('no basement')

df["FireplaceQu"] = df["FireplaceQu"].fillna("No Fireplace")

df["GarageType"] = df["GarageType"].fillna("No Garage")
df["GarageYrBlt"] = df["GarageYrBlt"].fillna("No Garage")
df["GarageFinish"] = df["GarageFinish"].fillna("No Garage")
df["GarageQual"] = df["GarageQual"].fillna("No Garage")
df["GarageCond"] = df["GarageCond"].fillna("No Garage")

# %% [markdown]
# ## Droping columns

# %%
df = df.drop(columns = ["PoolQC", "MiscFeature", "Alley", "Fence"])

# %%
df.shape
# Out:
# (1460, 77)

# %% [markdown]
# ## Cheking remaining missing values

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 77, dtype: int64

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # Phase-3 EDA

# %%
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Distribution of House Prices

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['SalePrice'],bins=30,kde=True)

plt.title("Distribution of House Prices")
plt.xlabel("Sale Price")
plt.ylabel("Number of Houses")
plt.show()

# %% [markdown]
# ## EDA Summary
#
# The target variable (SalePrice) was analyzed using descriptive statistics and a histogram. The average house price is approximately 180,921, while the median is $163,000. Most houses are priced between $100,000 and $220,000. The histogram shows a right-skewed distribution, indicating that a small number of expensive houses increase the average price. This suggests the presence of high-value houses (potential outliers), which should be considered during model building.

# %% [markdown]
# ## Correlation Analysis

# %%
correlation = df.corr(numeric_only=True)

# %%
correlation['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.472614
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.334771
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# ...

# %% [markdown]
# ### Top Features Correlated with SalePrice

# %%
correlation['SalePrice'].sort_values(ascending=False).head(10)
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(12,10))

sns.heatmap(
    correlation,
    cmap='coolwarm',
    linewidths=0.5
)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Heatmap of Top Correlated Features

# %%
top_features = correlation['SalePrice'].sort_values(ascending=False).head(10).index
plt.figure(figsize=(8,6))

sns.heatmap(
    df[top_features].corr(),
    annot=True,
    cmap='coolwarm',
      fmt=".2f"
    
)
plt.title("Top Features Correalated with SalesPrice")
plt.show()

# %% [markdown]
# ## Outlier Detection using Box Plot

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x=df['SalePrice'])
plt.title('Box Plot for Outliner')
plt.show()

# %% [markdown]
# ## Detecting Outliers using the IQR Method

# %% [markdown]
# ### Calculting Q1,Q3 & IQR

# %%
Q1 = df['SalePrice'].quantile(0.25)
Q3 = df['SalePrice'].quantile(0.75)

IQR = Q3 -Q1 
print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
# Out:
# Q1: 129975.0
# Q3: 214000.0
# IQR: 84025.0

# %% [markdown]
# ### Calculating Upper and Lower Limits

# %%
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR
print("Lower Limit:", lower_limit)
print("Upper Limit:", upper_limit)
# Out:
# Lower Limit: 3937.5
# Upper Limit: 340037.5

# %% [markdown]
# ### Finding Outliners

# %%
outliner = df[(df['SalePrice']< lower_limit )| (df['SalePrice'] > upper_limit)]
outliner
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 11      12          60       RL         85.0    11924   Pave      IR1
# 53      54          20       RL         68.0    50271   Pave      IR1
# 58      59          60       RL         66.0    13682   Pave      IR2
# 112    113          60       RL         77.0     9965   Pave      Reg
# 151    152          20       RL        107.0    13891   Pave      Reg
# ...    ...         ...      ...          ...      ...    ...      ...
# 1268  1269          50       RL         69.0    14100   Pave      IR1
# 1353  1354          50       RL         56.0    14720   Pave      IR1
# 1373  1374          20       RL         69.0    11400   Pave      Reg
# 1388  1389          20       RL         42.0    14892   Pave      IR1
# 1437  1438          20       RL         96.0    12444   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
outliner.shape[0]
# Out:
# 61

# %% [markdown]
# ## Scatter Plot: Living Area vs Sale Price

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['GrLivArea'],y=df['SalePrice'])
plt.title('Scatter Plot Living Area vs Sale Price')
plt.xlabel('Ground Living Area')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %% [markdown]
# ## Scatter Plot : Overall Quality vs Sales Price

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['OverallQual'],y=df['SalePrice'])
plt.title('Scatter Plot Overall Quality vs SalePrice')
plt.xlabel('Overall Quality')
plt.ylabel('Sale Price')
plt.show()

# %% [markdown]
# ## Categorical Feature Analysis

# %% [markdown]
# ## Overall Quality vs Sale Price

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['OverallQual'],y=df['SalePrice'])

plt.title("Overall Quality vs Sale Price")

plt.xlabel("Overall Quality")

plt.ylabel("Sale Price")

plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ## Average Sale Price by Neighborhood

# %% [markdown]
# ### Calculating Average Price

# %%
neighborhood_price = df.groupby('Neighborhood')['SalePrice'].mean().sort_values(ascending=False)
neighborhood_price
# Out:
# Neighborhood
# NoRidge    335295.317073
# NridgHt    316270.623377
# StoneBr    310499.000000
# Timber     242247.447368
# Veenker    238772.727273
# Somerst    225379.837209
# ClearCr    212565.428571
# Crawfor    210624.725490
# CollgCr    197965.773333
# Blmngtn    194870.882353
# Gilbert    192854.506329
# NWAmes     189050.068493
# SawyerW    186555.796610
# Mitchel    156270.122449
# NAmes      145847.080000
# NPkVill    142694.444444
# SWISU      142591.360000
# Blueste    137500.000000
# Sawyer     136793.135135
# OldTown    128225.300885
# Edwards    128219.700000
# BrkSide    124834.051724
# BrDale     104493.750000
# IDOTRR     100123.783784
# MeadowV     98576.470588
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### Bar Plot

# %%
plt.figure(figsize=(12,6))
sns.barplot(
    x=neighborhood_price.index,
    y=neighborhood_price.values
)
plt.title("Average Sale Price by Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Average Sale Price")

plt.xticks(rotation=90)

plt.show()

# %%
neighborhood_price.head()
# Out:
# Neighborhood
# NoRidge    335295.317073
# NridgHt    316270.623377
# StoneBr    310499.000000
# Timber     242247.447368
# Veenker    238772.727273
# Name: SalePrice, dtype: float64
